# %% [markdown]
# <a href="https://colab.research.google.com/github/fauzan-al27/UAS-Prak.AI/blob/main/UAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Fuzzi Tahani**

# %%
# !pip install -U scikit-fuzzy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 993 kB 5.1 MB/s
# ...
#   Created wheel for scikit-fuzzy: filename=scikit_fuzzy-0.4.2-py3-none-any.whl size=894089 sha256=cbe0617b8fdcaf901ee8ef8d5c0fe7affe54c9ff55afe24092b7a5bccb46780e
#   Stored in directory: /root/.cache/pip/wheels/d5/74/fc/38588a3d2e3f34f74588e6daa3aa5b0a322bd6f9420a707131
# Successfully built scikit-fuzzy
# ...

# %%
# import library

import numpy as np
import pandas as pd
import skfuzzy as fuzz
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
print ("Angka 1 dibelakang tahun merupakan semester ganjil")
print ("Angka 2 dibelakang tahun merupakan semester genap")

rm = pd.read_csv(r"/content/sample_data/rekap_mahasiswa.csv")
rm
# Out:
# Angka 1 dibelakang tahun merupakan semester ganjil
# Angka 2 dibelakang tahun merupakan semester genap
#     semester  jumlah
# 0     2021.1     302
# 1     2020.2     337
# 2     2020.1     348
# 3     2019.2     319
# 4     2019.1     366
# 5     2018.2     286
# 6     2018.1     345
# 7     2017.2     273
# 8     2017.1     251
# 9     2016.2     229
# 10    2016.1     244
# 11    2015.2     203
# 12    2015.1     254
# 13    2014.2     217
# 14    2014.1     247
# 15    2013.2     252
# 16    2013.1     299
# 17    2012.2     294
# 18    2012.1     362
# 19    2011.2     282
# 20    2011.1     304
# 21    2010.2     265
# 22    2010.1     273
# 23    2009.2     282
# 24    2009.1     288

# %%
def Range (_low, _high, _step):
  subjektif = np.arange(_low, _high, _step)
  return subjektif

def FuzzyAlgoritm (_rule, _range, _title):
  lo = fuzz.trimf(_range, _rule[0])
  hi = fuzz.trimf(_range, _rule[1])

  fig, ax = plt.subplots (nrows=1, figsize=(6, 3))
  ax.plot(_range, lo, 'g', linewidth = 1.5, label = 'rendah')
  ax.plot(_range, hi, 'r', linewidth = 1.5, label = 'tinggi')

  ax.set_title(_title)
  ax.legend()

  ax.spines['top'].set_visible(False)
  ax.spines['right'].set_visible(False)
  ax.get_xaxis().tick_bottom()
  ax.get_yaxis().tick_left()

  plt.tight_layout()
  plt.show()

  return lo, hi

# %%
xbanyak_mahasiswa = Range(203, 366, 1)
rbanyak_mahasiswa = np.array([
                              [203, 247, 282],
                              [254, 302, 366]
])

lo_banyak_mahasiswa, hi_banyak_mahasiswa = FuzzyAlgoritm(rbanyak_mahasiswa, xbanyak_mahasiswa, 'Rentang Jumlah Mahasiswa')
